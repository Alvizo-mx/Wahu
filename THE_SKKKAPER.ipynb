# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests
import re

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException, StaleElementReferenceException
from selenium.webdriver.common.action_chains import ActionChains

from fake_useragent import UserAgent

import time
from datetime import datetime



def igualar_longitudes(arr1, arr2, valor_a_agregar='Sin datos'):
    len_arr1 = len(arr1)
    len_arr2 = len(arr2)

    if len_arr1 < len_arr2:
        # Agregar 'valor_a_agregar' al arreglo más corto hasta que tengan la misma longitud
        diferencia = len_arr2 - len_arr1
        arr1.extend([valor_a_agregar] * diferencia)
    elif len_arr2 < len_arr1:
        # Agregar 'valor_a_agregar' al arreglo más corto hasta que tengan la misma longitud
        diferencia = len_arr1 - len_arr2
        arr2.extend([valor_a_agregar] * diferencia)

# Ejemplo de uso
arr1 = [1, 2, 3, 4,5,6]
arr2 = ['a', 'b', 'c']

# Asegurarse de que ambos arreglos tengan la misma longitud
igualar_longitudes(arr1, arr2)

# Ahora ambos arreglos tienen la misma longitud
print(arr1)
print(arr2)
# Out:
# [1, 2, 3, 4, 5, 6]
# ['a', 'b', 'c', 'Sin datos', 'Sin datos', 'Sin datos']

# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests
import re

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException, StaleElementReferenceException
from selenium.webdriver.common.action_chains import ActionChains

from fake_useragent import UserAgent

import time
from datetime import datetime
import random


# Variables de tipo listas donde se guardara nuestra informacion 

Fecha = []
Id_stock = []
URL_auto = []
URL_image = []
Estatus = []
T_invenario = []
Marca = []
Modelo = []
Año = []
Km = []
Version = []
Transmision = []
Color = []
Costo_normal = []
Oferta = []
Mensualidades = []
Ubicacion = []

URL_actual = []
Tamaño_coches = []
Posicion_coche = []
Total_paginas = []



# https://www.kavak.com/mx/seminuevos/?
url = 'https://www.kavak.com/mx/seminuevos/?' 
 
# Utiliza Beautiful Soup para analizar el total de paginas en este momento
response = requests.get(url)
print(response.status_code)
soup = BeautifulSoup(response.content,"html.parser")

n_paginas = soup.find_all("a",{'class': 'results_results__pagination-item__2wkpb'})[4].get_text()

# Cambiando el agente de usuario por primera vez
options = Options()
ua = UserAgent()
user_agent = ua.random

# Define los encabezados de la solicitud
headers = {
    'User-Agent': user_agent
}


# Codigo: for i in range(int(n_paginas) - 1):

for i in range(int(n_paginas)):
  # https://www.kavak.com/mx/seminuevos/?page=0                         normal
  # https://www.kavak.com/mx/seminuevos/?order=higher_price&page=1      mayor precio
  # https://www.kavak.com/mx/seminuevos/?order=lower_mileage&page=1     menos kilometraje
  url ="https://www.kavak.com/mx/seminuevos/?order=higher_price&page="+ str(i) 
  response=requests.get(url, headers=headers) 

  if i % 20 == 0:
    # Cambiando el agente de usuario 
    options = Options()
    ua = UserAgent()
    user_agent = ua.random

  # Si el estatus de la pagina, es bueno entonces entramos de lo contrario agregamos info de el error y continuamos 
  if response.status_code == 200:
    # Configuracion de selenium
    options = Options()
    options.add_argument("--disable-blink-features=AutomationControlled")  # Evita que el sitio web detecte que estás utilizando Selenium
    options.add_argument("--start-maximized")  # Inicia el navegador maximizado
    options.add_argument(f'--user-agent={user_agent}')
    driver_path = r'C:\Users\Wahu\Documents\chromedriver-win64\chromedriver.exe' 
    options.add_argument(f"webdriver.chrome.driver={driver_path}")

    driver = webdriver.Chrome(options=options) #Creamos un driver cada vez que visitamos una página
    driver.get(url)

    # Espera a que la página cargue completamente
    time.sleep(random.uniform(3, 6))

    # Hace scroll hacia abajo suavemente utilizando JavaScript
    scroll_height = driver.execute_script("return Math.max( document.body.scrollHeight, document.body.offsetHeight, document.documentElement.clientHeight, document.documentElement.scrollHeight, document.documentElement.offsetHeight);")

    scroll_increment = 100  # Ajusta según sea necesario
    num_scrolls = int(scroll_height / scroll_increment)

    for _ in range(num_scrolls):
      driver.execute_script("window.scrollTo(0, {});".format(scroll_increment))
      time.sleep(0.4)  # Ajusta según sea necesario para dar tiempo a cargar los elementos
      scroll_increment += 150  # Ajusta según sea necesario para el tamaño de la pagina


    # Obtiene el contenido HTML de la página después de interactuar con ella
    html = driver.page_source

    # Utiliza Beautiful Soup para analizar el contenido HTML
    soup = BeautifulSoup(html, 'html.parser')

    # Espera un poco más después del último scroll
    time.sleep(random.uniform(3, 6))

    
    # Extrayendo la informacion
    for i in range(len(soup.find_all("a",{'class': 'card-product_cardProduct__3qZCJ'}))):
      fecha_actual = datetime.now()
      Fecha.append(fecha_actual)

      find_id = soup.find_all("a",{'class': 'card-product_cardProduct__3qZCJ'})[i].get("data-testid")
      kkk_id = find_id.split('-')[-1]
      Id_stock.append(kkk_id)
      
      URL_auto.append(soup.find_all("a",{'class': 'card-product_cardProduct__3qZCJ'})[i].get('href'))

      URL_image.append(soup.find_all("div",{'class': 'card-product_cardProduct__imageContainer__nn_0a'})[i].find("img").get('src'))

      Estatus.append(soup.find_all("div",{'class': 'card-product_cardProduct__imageContainer__nn_0a'})[i].get_text("div",{'class': 'card-product_cardProduct__badgesContainer__V35qk'}))

      T_invenario.append("Sin datos")

      auto = soup.find_all("h3",{'class': 'card-product_cardProduct__title__RR0CK'})[i].get_text()
      # Creamos un separador
      separador = auto.split(' • ')
      # Ahora 'separador' es una lista que contiene cada parte separada
      Marca.append(separador[0])
      Modelo.append(separador[1])

      Caracteristicas = soup.find_all("p",{'class': 'card-product_cardProduct__subtitle__hbN2a'})[i].get_text()
      # Creamos un separador
      elementos = Caracteristicas.split(' • ')
      # Ahora 'elementos' es una lista que contiene cada parte separada
      Año.append(elementos[0])
      Km.append(elementos[1])
      Version.append(elementos[2])
      Transmision.append(elementos[3])
                                       
      # Usando un condicional para manejar el NoneType
      costo_norm = soup.find_all('div',{'class': 'card-product_cardProduct__priceContainer__3T0tb'})[i].find('span', {'class':'card-product_cardProduct__price__Er33n'})

      if costo_norm is not None:
          Costo_normal.append(costo_norm.text)
      else:
          Costo_normal.append("Sin datos")

      oferta_text = soup.find_all('div', {'class': 'card-product_cardProduct__priceMainContainer__ex_hf'})[i].find('span', {'class': 'amount_uki-amount__large__price__2NvVx'})
      if oferta_text:
          Oferta.append(oferta_text.text)
      else:
          Oferta.append("Sin datos") 

      impar_num = 2 * i + 1  # Calcula el i-ésimo número impar
      mensualidad_text = soup.find_all('span',{'class': 'card-product_cardProduct__priceSection__2GKb8'})[impar_num]
      if mensualidad_text:
          Mensualidades.append(mensualidad_text.text)
      else:
          Mensualidades.append("Sin datos")

      Ubicacion.append(soup.find_all('div',{'class': 'card-product_cardProduct__footer__MQKa_'})[i].get_text())

      # Informacion para analizar
      URL_actual.append(driver.current_url)

      Tamaño_coches.append(len(soup.find_all("a",{'class': 'card-product_cardProduct__3qZCJ'})))

      Posicion_coche.append(i)

      Total_paginas.append(n_paginas)


    driver.close() #Cerramos el driver una vez tenemos la información
        
  else:
    fecha_actual = datetime.now()
    Fecha.append(fecha_actual)
    Id_stock.append(url)
    URL_auto.append("URL_ERROR")
    URL_image.append("URL_ERROR")
    Estatus.append("URL_ERROR")
    T_invenario.append("URL_ERROR")
    Marca.append("URL_ERROR")
    Modelo.append("URL_ERROR")
    Año.append("URL_ERROR")
    Km.append("URL_ERROR")
    Version.append("URL_ERROR")
    Transmision.append("URL_ERROR")
    Costo_normal.append("URL_ERROR")
    Oferta.append("URL_ERROR")
    Mensualidades.append("URL_ERROR")
    Ubicacion.append("URL_ERROR")
    URL_actual.append("URL_ERROR")
    Tamaño_coches.append("URL_ERROR")
    Posicion_coche.append("URL_ERROR")
    Total_paginas.append("URL_ERROR")
    continue
    
    
driver.quit() #Cerramos el driver una vez tenemos la información
# Out:
# 200

# %%
#soup.find_all("script")

# %%
"""# Asegurarse de que los arreglos tengan la misma longitud
igualar_longitudes(Fecha, Id_stock)
igualar_longitudes(Id_stock, URL_actual)
igualar_longitudes(URL_actual, Tamaño_coches)
igualar_longitudes(Tamaño_coches, Posicion_coche)
igualar_longitudes(Posicion_coche, Total_paginas)
igualar_longitudes(Total_paginas, URL_auto)
igualar_longitudes(URL_auto, URL_image)
igualar_longitudes(URL_image, Estatus)
igualar_longitudes(Estatus, Marca)
igualar_longitudes(Marca, Modelo)
igualar_longitudes(Modelo, Version)
igualar_longitudes(Version, Año)
igualar_longitudes(Año, Km)
igualar_longitudes(Km, Transmision)
igualar_longitudes(Transmision, Color)
igualar_longitudes(Costo_normal, Oferta)
igualar_longitudes(Oferta, Mensualidades)
igualar_longitudes(Mensualidades, Ubicacion)"""
# Out:
# '# Asegurarse de que los arreglos tengan la misma longitud\nigualar_longitudes(Fecha, Id_stock)\nigualar_longitudes(Id_stock, URL_actual)\nigualar_longitudes(URL_actual, Tamaño_coches)\nigualar_longitudes(Tamaño_coches, Posicion_coche)\nigualar_longitudes(Posicion_coche, Total_paginas)\nigualar_longitudes(Total_paginas, URL_auto)\nigualar_longitudes(URL_auto, URL_image)\nigualar_longitudes(URL_image, Estatus)\nigualar_longitudes(Estatus, Marca)\nigualar_longitudes(Marca, Modelo)\nigualar_longitudes(Modelo, Version)\nigualar_longitudes(Version, Año)\nigualar_longitudes(Año, Km)\nigualar_longitudes(Km, Transmision)\nigualar_longitudes(Transmision, Color)\nigualar_longitudes(Costo_normal, Oferta)\nigualar_longitudes(Oferta, Mensualidades)\nigualar_longitudes(Mensualidades, Ubicacion)'

# %%
# Creamos un archivo pandas con los arreglos 
THE_SKKKAPER_Jupyter_ = pd.DataFrame({'Fecha':Fecha,'Id_stock':Id_stock,'URL_actual':URL_actual,'Tamaño_coches':Tamaño_coches,'Posicion_coche':Posicion_coche,
                                        'Total_paginas':Total_paginas ,'URL_auto':URL_auto,
                                        'URL_image':URL_image,'Estatus':Estatus,'T_invenario':T_invenario,'Marca':Marca,'Modelo':Modelo,'Version':Version,
                                        'Año':Año,'Km':Km,'Transmision':Transmision,
                                        'Costo_normal':Costo_normal, 'Oferta':Oferta,'Mensualidades':Mensualidades,'Ubicacion':Ubicacion})

# %%
# Rellenando valores NaN

THE_SKKKAPER_Jupyter_.fillna("Sin datos", inplace=True)

# %%
# Rellenando la columna estatus si tiene alguna cadena vacia

THE_SKKKAPER_Jupyter_['Estatus'].replace('', 'Sin etiqueta', inplace=True)
# Out:
# C:\Users\Wahu\AppData\Local\Temp\ipykernel_13548\845437468.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   THE_SKKKAPER_Jupyter_['Estatus'].replace('', 'Sin etiqueta', inplace=True)

# %%
THE_SKKKAPER_Jupyter_
# Out:
#                           Fecha Id_stock  \
# 0    2024-11-13 16:49:03.193910   356960
# 1    2024-11-13 16:49:03.243889   339351
# 2    2024-11-13 16:49:03.293861   357162
# 3    2024-11-13 16:49:03.344347   352752
# 4    2024-11-13 16:49:03.394323   360398
# ...                         ...      ...
# 8055 2024-11-13 20:14:36.499096   300741
# 8056 2024-11-13 20:14:36.529082   347740
# 8057 2024-11-13 20:14:36.562548   329609
# 8058 2024-11-13 20:14:36.592535   349610
# 8059 2024-11-13 20:14:36.622547   351554
#
#                                              URL_actual  Tamaño_coches  \
# 0     https://www.kavak.com/mx/seminuevos?order=high...             30
# 1     https://www.kavak.com/mx/seminuevos?order=high...             30
# 2     https://www.kavak.com/mx/seminuevos?order=high...             30
# 3     https://www.kavak.com/mx/seminuevos?order=high...             30
# 4     https://www.kavak.com/mx/seminuevos?order=high...             30
# ...                                                 ...            ...
# 8055  https://www.kavak.com/mx/seminuevos?order=high...             20
# 8056  https://www.kavak.com/mx/seminuevos?order=high...             20
# 8057  https://www.kavak.com/mx/seminuevos?order=high...             20
# 8058  https://www.kavak.com/mx/seminuevos?order=high...             20
# 8059  https://www.kavak.com/mx/seminuevos?order=high...             20
#
#       Posicion_coche Total_paginas  \
# 0                  0           270
# 1                  1           270
# 2                  2           270
# 3                  3           270
# 4                  4           270
# ...              ...           ...
# 8055              15           270
# 8056              16           270
# 8057              17           270
# 8058              18           270
# 8059              19           270
#
#                                                URL_auto  \
# 0     https://www.kavak.com/mx/usado/audi-q7-30_mhev...
# 1     https://www.kavak.com/mx/usado/chevrolet-cheye...
# 2     https://www.kavak.com/mx/usado/bmw-z4-30_m40i_...
# 3     https://www.kavak.com/mx/usado/ford-mustang_ma...
# 4     https://www.kavak.com/mx/usado/lincoln-navigat...
# ...                                                 ...
# 8055  https://www.kavak.com/mx/usado/renault-sandero...
# 8056  https://www.kavak.com/mx/usado/chevrolet-matiz...
# 8057  https://www.kavak.com/mx/usado/renault-stepway...
# 8058  https://www.kavak.com/mx/usado/chevrolet-matiz...
# 8059  https://www.kavak.com/mx/usado/chevrolet-matiz...
#
#                                               URL_image       Estatus  \
# 0     https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...  Sin etiqueta
# 1     https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...  Sin etiqueta
# 2     https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...  Sin etiqueta
# 3     https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...  Sin etiqueta
# 4     https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...  Sin etiqueta
# ...                                                 ...           ...
# 8055  https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...      Apartado
# 8056  https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...      Apartado
# 8057  https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...      Apartado
# 8058  https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...      Apartado
# 8059  https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...      Apartado
#
#      T_invenario      Marca          Modelo  \
# 0      Sin datos       Audi              Q7
# 1      Sin datos  Chevrolet        Cheyenne
# 2      Sin datos        Bmw              Z4
# 3      Sin datos       Ford  Mustang Mach-E
# 4      Sin datos    Lincoln       Navigator
# ...          ...        ...             ...
# 8055   Sin datos    Renault         Sandero
# 8056   Sin datos  Chevrolet           Matiz
# 8057   Sin datos    Renault         Stepway
# 8058   Sin datos  Chevrolet           Matiz
# 8059   Sin datos  Chevrolet           Matiz
#
#                                     Version   Año          Km Transmision  \
# 0          3.0 MHEV 55 TFSI S LINE AUTO 4WD  2022   18,822 km  Automático
# 1     6.2 CHEYENNE HIGH CREW CAB G AUTO 4WD  2022   14,685 km  Automático
# 2                             3.0 M40I AUTO  2021   28,663 km  Automático
# 3         BEV 99KWH GT PERFORMANCE AUTO AWD  2022   25,881 km  Automático
# 4                      3.5 RESERVE AUTO 4WD  2019   77,140 km  Automático
# ...                                     ...   ...         ...         ...
# 8055                      1.6 EXPRESSION AT  2017  118,616 km  Automático
# 8056                            1.0 AC B MT  2015   95,891 km      Manual
# 8057                       1.6 DYNAMIQUE MT  2013   91,234 km      Manual
# 8058                               1.0 A MT  2014   94,537 km      Manual
# 8059                            1.0 AC B MT  2014  109,796 km      Manual
#
#      Costo_normal     Oferta   Mensualidades         Ubicacion
# 0       Sin datos  1,167,999  $13,838 / mes*  Ciudad de México
# 1       Sin datos  1,108,999  $13,171 / mes*  Ciudad de México
# 2       Sin datos  1,083,999  $12,889 / mes*  Ciudad de México
# 3       Sin datos  1,067,999  $12,708 / mes*  Ciudad de México
# 4       Sin datos    910,999  $10,933 / mes*            Puebla
# ...           ...        ...             ...               ...
# 8055    Sin datos  Sin datos                  Ciudad de México
# 8056    Sin datos  Sin datos                  Ciudad de México
# 8057    Sin datos  Sin datos                       Guadalajara
# 8058    Sin datos  Sin datos                  Ciudad de México
# 8059    Sin datos  Sin datos                  Ciudad de México
#
# [8060 rows x 20 columns]

# %%
# Obtén la fecha actual con el formato dia-mes-año
# fecha_actual = datetime.now().strftime("%d-%m-%Y")
fecha_actual = datetime.now().strftime("%d-%m-%Y-%H")

# Agrega la fecha al nombre del DataFrame
nombre_del_df = f"THE_SKKKAPER_Jupyter_{fecha_actual}"

# Guarda el DataFrame en un archivo de CSV con el nuevo nombre
ruta_excel = f"{nombre_del_df}.csv" # Para excel usar .xlsx como extension
# THE_SKKKAPER_.to_excel(ruta_excel, index=False)

# Guarda el DataFrame en un archivo de CSV con el nuevo nombre
THE_SKKKAPER_Jupyter_.to_csv(ruta_excel, sep ="|" ,index=False)

# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests
import re

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException, StaleElementReferenceException
from selenium.webdriver.common.action_chains import ActionChains

from fake_useragent import UserAgent

import time
from datetime import datetime
import random



def igualar_longitudes(arr1, arr2, valor_a_agregar='Sin datos'):
    len_arr1 = len(arr1)
    len_arr2 = len(arr2)

    if len_arr1 < len_arr2:
        # Agregar 'valor_a_agregar' al arreglo más corto hasta que tengan la misma longitud
        diferencia = len_arr2 - len_arr1
        arr1.extend([valor_a_agregar] * diferencia)
    elif len_arr2 < len_arr1:
        # Agregar 'valor_a_agregar' al arreglo más corto hasta que tengan la misma longitud
        diferencia = len_arr1 - len_arr2
        arr2.extend([valor_a_agregar] * diferencia)



# Variables de tipo listas donde se guardara nuestra informacion 

Fecha = []
Id_stock = []
URL_auto = []
URL_image = []
Estatus = []
T_invenario = []
Marca = []
Modelo = []
Año = []
Km = []
Version = []
Transmision = []
Color = []
Costo_normal = []
Oferta = []
Mensualidades = []
Ubicacion = []

URL_actual = []
Tamaño_coches = []
Posicion_coche = []
Total_paginas = []



# https://www.kavak.com/mx/seminuevos/?
url = 'https://www.kavak.com/mx/seminuevos?page=0' 
 
# Utiliza Beautiful Soup para analizar el total de paginas en este momento
response = requests.get(url)
print(response.status_code)
soup = BeautifulSoup(response.content,"html.parser")

n_paginas = soup.find_all("span",{'class': 'total'})[0].get_text()

# Cambiando el agente de usuario por primera vez
options = Options()
ua = UserAgent()
user_agent = ua.random

# Define los encabezados de la solicitud
headers = {
    'User-Agent': user_agent
}


# Codigo: for i in range(int(n_paginas) - 1):

for i in range(int(n_paginas)):
  # https://www.kavak.com/mx/seminuevos/?page=0                         normal
  # https://www.kavak.com/mx/seminuevos/?order=higher_price&page=1      mayor precio
  # https://www.kavak.com/mx/seminuevos/?order=lower_mileage&page=1     menos kilometraje
  url ="https://www.kavak.com/mx/seminuevos/?order=higher_price&page="+ str(i) 
  try: 
    response=requests.get(url, headers=headers) 

    if i % 20 == 0:
      # Cambiando el agente de usuario 
      options = Options()
      ua = UserAgent()
      user_agent = ua.random

    # Si el estatus de la pagina, es bueno entonces entramos de lo contrario agregamos info de el error y continuamos 
    if response.status_code == 200:
      # Configuracion de selenium
      options = Options()
      options.add_argument("--disable-blink-features=AutomationControlled")  # Evita que el sitio web detecte que estás utilizando Selenium
      options.add_argument("--start-maximized")  # Inicia el navegador maximizado
      options.add_argument(f'--user-agent={user_agent}')
      driver_path = r'C:\Users\Wahu\Documents\chromedriver-win64\chromedriver.exe' 
      options.add_argument(f"webdriver.chrome.driver={driver_path}")

      driver = webdriver.Chrome(options=options) #Creamos un driver cada vez que visitamos una página
      driver.get(url)

      # Espera a que la página cargue completamente
      time.sleep(random.uniform(3, 6))

      # Hace scroll hacia abajo suavemente utilizando JavaScript
      scroll_height = driver.execute_script("return Math.max( document.body.scrollHeight, document.body.offsetHeight, document.documentElement.clientHeight, document.documentElement.scrollHeight, document.documentElement.offsetHeight);")

      scroll_increment = 100  # Ajusta según sea necesario
      num_scrolls = int(scroll_height / scroll_increment)

      for _ in range(num_scrolls):
        driver.execute_script("window.scrollTo(0, {});".format(scroll_increment))
        time.sleep(0.4)  # Ajusta según sea necesario para dar tiempo a cargar los elementos
        scroll_increment += 260  # Ajusta según sea necesario para el tamaño de la pagina


      # Obtiene el contenido HTML de la página después de interactuar con ella
      html = driver.page_source

      # Utiliza Beautiful Soup para analizar el contenido HTML
      soup = BeautifulSoup(html, 'html.parser')

      # Espera un poco más después del último scroll
      time.sleep(random.uniform(3, 6))

      
      # Extrayendo la informacion
      for i in range(len(soup.find_all("a",{'class': 'card-product'}))):
        fecha_actual = datetime.now()
        Fecha.append(fecha_actual)
        
        URL_auto.append(soup.find_all("a",{'class': 'card-product'})[i].get('href'))

        URL_image.append(soup.find_all("img")[i+3].get('src'))

        Estatus.append(soup.find_all("div",{'class': 'badge'})[i].get_text())

        T_invenario.append("Sin datos")

        auto = soup.find_all("div",{'class': 'card-header'})[i].select("h3",{'class': 'title'})[0].get_text()
        # Creamos un separador
        separador = auto.split(' • ')
        # Ahora 'separador' es una lista que contiene cada parte separada
        Marca.append(separador[0])
        Modelo.append(separador[1])

        Caracteristicas = soup.find_all("div",{'class': 'card-header'})[i].select("p",{'class': 'subtitle'})[0].get_text()
        # Creamos un separador
        elementos = Caracteristicas.split(' • ')
        # Ahora 'elementos' es una lista que contiene cada parte separada
        Año.append(elementos[0])
        Km.append(elementos[1])
        Version.append(elementos[2])
        Transmision.append(elementos[3])

                                            
        Costo_normal.append(soup.find_all("div",{'class': 'price-item-header'})[i].get_text())

        Oferta.append(soup.find_all("div",{'class': 'price-item-main'})[i].get_text())

        Mensualidades.append(soup.find_all("div",{'class': 'price-item-footer'})[i].get_text())

        Ubicacion.append(soup.find_all("span",{'class': 'info'})[i].get_text())

        # Informacion para analizar
        URL_actual.append(driver.current_url)

        Tamaño_coches.append(len(soup.find_all("a",{'class': 'card-product'})))

        Posicion_coche.append(i)

        Total_paginas.append(soup.find_all("span",{'class': 'total'})[0].get_text())

      

      # Guardamos la informacion donde se encuentran el id_stock
      id_scripts = soup.find_all("script", {'id': "serverApp-state"})[0].get_text()

      # Definir la expresión regular para capturar la información
      patron = r'id&q;:&q;(\d+)&q;'

      # Buscar todas las coincidencias en el texto
      coincidencias_id = re.findall(patron, id_scripts)

      for i in range(len(soup.find_all("a",{'class': 'card-product'}))):
          try:
            Id_stock.append(coincidencias_id[i])
          except IndexError:
            Id_stock.append("Sin datos")


      # Guardamos la informacion donde se encuentran los colores
      c_scripts = soup.find_all("script", {'id': "serverApp-state"})[0].get_text()

      # Definir la expresión regular para capturar la información
      patron = r'&q;color&q;:&q;([^&]+)&q;,'

      # Buscar todas las coincidencias en el texto
      coincidencias_c = re.findall(patron, c_scripts)
      coincidencias_c_f = coincidencias_c[14:44]

      for i in range(len(soup.find_all("a",{'class': 'card-product'}))):
        try:
          Color.append(coincidencias_c_f[i])
        except IndexError:  
          Color.append("Sin datos")


      driver.close() #Cerramos el driver una vez tenemos la información
          
    else:
      fecha_actual = datetime.now()
      Fecha.append(fecha_actual)
      Id_stock.append(url)
      URL_auto.append("URL_ERROR")
      URL_image.append("URL_ERROR")
      Estatus.append("URL_ERROR")
      T_invenario.append("URL_ERROR")
      Marca.append("URL_ERROR")
      Modelo.append("URL_ERROR")
      Año.append("URL_ERROR")
      Km.append("URL_ERROR")
      Version.append("URL_ERROR")
      Transmision.append("URL_ERROR")
      Costo_normal.append("URL_ERROR")
      Oferta.append("URL_ERROR")
      Mensualidades.append("URL_ERROR")
      Ubicacion.append("URL_ERROR")
      URL_actual.append("URL_ERROR")
      Tamaño_coches.append("URL_ERROR")
      Posicion_coche.append("URL_ERROR")
      Total_paginas.append("URL_ERROR")
      continue
    
    
  except Exception as e:
    print("Error general:", e)
# Out:
# 200
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[248], line 74
#      71 print(response.status_code)
#      72 soup = BeautifulSoup(response.content,"html.parser")
# ---> 74 n_paginas = soup.find_all("span",{'class': 'total'})[0].get_text()
#      76 # Cambiando el agente de usuario por primera vez
#      77 options = Options()
#
# IndexError: list index out of range

# %%
"""# Asegurarse de que los arreglos tengan la misma longitud
igualar_longitudes(Fecha, Id_stock)
igualar_longitudes(Id_stock, URL_actual)
igualar_longitudes(URL_actual, Tamaño_coches)
igualar_longitudes(Tamaño_coches, Posicion_coche)
igualar_longitudes(Posicion_coche, Total_paginas)
igualar_longitudes(Total_paginas, URL_auto)
igualar_longitudes(URL_auto, URL_image)
igualar_longitudes(URL_image, Estatus)
igualar_longitudes(Estatus, Marca)
igualar_longitudes(Marca, Modelo)
igualar_longitudes(Modelo, Version)
igualar_longitudes(Version, Año)
igualar_longitudes(Año, Km)
igualar_longitudes(Km, Transmision)
igualar_longitudes(Transmision, Color)
igualar_longitudes(Color, Costo_normal)
igualar_longitudes(Costo_normal, Oferta)
igualar_longitudes(Oferta, Mensualidades)
igualar_longitudes(Mensualidades, Ubicacion)"""


# Creamos un archivo pandas con los arreglos 
THE_SKKKAPER_Jupyter_ = pd.DataFrame({'Fecha':Fecha,'Id_stock':Id_stock,'URL_actual':URL_actual,'Tamaño_coches':Tamaño_coches,'Posicion_coche':Posicion_coche,
                                        'Total_paginas':Total_paginas ,'URL_auto':URL_auto,
                                        'URL_image':URL_image,'Estatus':Estatus,'T_invenario':T_invenario,'Marca':Marca,'Modelo':Modelo,'Version':Version,
                                        'Año':Año,'Km':Km,'Transmision':Transmision, 'Color': Color,
                                        'Costo_normal':Costo_normal, 'Oferta':Oferta,'Mensualidades':Mensualidades,'Ubicacion':Ubicacion})


# Rellenando valores NaN
THE_SKKKAPER_Jupyter_.fillna("Sin datos", inplace=True)


# Rellenando la columna estatus si tiene alguna cadena vacia
THE_SKKKAPER_Jupyter_['Estatus'].replace('', 'Sin etiqueta', inplace=True)

THE_SKKKAPER_Jupyter_
# Out:
#                           Fecha Id_stock  \
# 0    2024-10-15 06:42:39.498094   113009
# 1    2024-10-15 06:42:39.555480   339351
# 2    2024-10-15 06:42:39.612319   348335
# 3    2024-10-15 06:42:39.666590   340359
# 4    2024-10-15 06:42:39.724298   352752
# ...                         ...      ...
# 7503 2024-10-15 08:42:12.215835   332279
# 7504 2024-10-15 08:42:12.250664   344126
# 7505 2024-10-15 08:42:12.286601   341682
# 7506 2024-10-15 08:42:12.321476   343051
# 7507 2024-10-15 08:42:12.357821   351554
#
#                                              URL_actual  Tamaño_coches  \
# 0     https://www.kavak.com/mx/seminuevos?order=high...             30
# 1     https://www.kavak.com/mx/seminuevos?order=high...             30
# 2     https://www.kavak.com/mx/seminuevos?order=high...             30
# 3     https://www.kavak.com/mx/seminuevos?order=high...             30
# 4     https://www.kavak.com/mx/seminuevos?order=high...             30
# ...                                                 ...            ...
# 7503  https://www.kavak.com/mx/seminuevos?order=high...              8
# 7504  https://www.kavak.com/mx/seminuevos?order=high...              8
# 7505  https://www.kavak.com/mx/seminuevos?order=high...              8
# 7506  https://www.kavak.com/mx/seminuevos?order=high...              8
# 7507  https://www.kavak.com/mx/seminuevos?order=high...              8
#
#       Posicion_coche Total_paginas  \
# 0                  0          251
# 1                  1          251
# 2                  2          251
# 3                  3          251
# 4                  4          251
# ...              ...           ...
# 7503               3          251
# 7504               4          251
# 7505               5          251
# 7506               6          251
# 7507               7          251
#
#                                                URL_auto  \
# 0     https://www.kavak.com/mx/usado/jaguar-i_pace-9...
# 1     https://www.kavak.com/mx/usado/chevrolet-cheye...
# 2     https://www.kavak.com/mx/usado/chevrolet-cheye...
# 3     https://www.kavak.com/mx/usado/porsche-cayenne...
# 4     https://www.kavak.com/mx/usado/ford-mustang_ma...
# ...                                                 ...
# 7503  https://www.kavak.com/mx/usado/ford-fusion-30_...
# 7504  https://www.kavak.com/mx/usado/peugeot-207-16_...
# 7505  https://www.kavak.com/mx/usado/ford-fiesta-16_...
# 7506  https://www.kavak.com/mx/usado/chevrolet-matiz...
# 7507  https://www.kavak.com/mx/usado/chevrolet-matiz...
#
#                                               URL_image       Estatus  \
# 0     https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...  Sin etiqueta
# 1     https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...  Sin etiqueta
# 2     https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...  Sin etiqueta
# 3     https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...  Sin etiqueta
# 4     https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...  Sin etiqueta
# ...                                                 ...           ...
# 7503  https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...      Apartado
# 7504  https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...      Apartado
# 7505  https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...      Apartado
# 7506  https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...      Apartado
# 7507  https://images.prd.kavak.io/eyJidWNrZXQiOiJrYX...      Apartado
#
#      T_invenario  ...          Modelo                                Version  \
# 0      Sin datos  ...          I-PACE      90KWH P400 FIRST EDITION AUTO 4WD
# 1      Sin datos  ...        Cheyenne  6.2 CHEYENNE HIGH CREW CAB G AUTO 4WD
# 2      Sin datos  ...        Cheyenne  6.2 CHEYENNE HIGH CREW CAB G AUTO 4WD
# 3      Sin datos  ...         Cayenne                         2.9 S AUTO 4WD
# 4      Sin datos  ...  Mustang Mach-E      BEV 99KWH GT PERFORMANCE AUTO AWD
# ...          ...  ...             ...                                    ...
# 7503   Sin datos  ...          Fusion                           3.0 SE V6 AT
# 7504   Sin datos  ...             207                       1.6 ALLURE 5P MT
# 7505   Sin datos  ...          Fiesta   1.6 FIESTA IKON HATCH AMBIENTE AA MT
# 7506   Sin datos  ...           Matiz                            1.0 AC B MT
# 7507   Sin datos  ...           Matiz                            1.0 AC B MT
#
#        Año          Km Transmision    Color     Costo_normal           Oferta  \
# 0     2019    4,545 km  Automático   Blanco   Precio desde     $  1,226,999
# 1     2022   14,685 km  Automático  primary   Precio desde     $  1,151,999
# 2     2022   16,760 km  Automático   Blanco   Precio desde     $  1,119,999
# 3     2019   65,644 km  Automático     Gris   Precio desde     $  1,117,999
# 4     2022   25,881 km  Automático     Gris   Precio desde     $  1,097,999
# ...    ...         ...         ...      ...              ...              ...
# 7503  2012  102,151 km  Automático    Negro   Precio desde       $  107,999
# 7504  2012  117,378 km      Manual   Blanco   Precio desde       $  106,999
# 7505  2014  109,134 km      Manual     Azul   Precio desde       $  100,999
# 7506  2015  116,541 km      Manual     Rojo   Precio desde        $  99,999
# 7507  2014  109,796 km      Manual     Rojo   Precio desde        $  95,999
#
#          Mensualidades         Ubicacion
# 0      $14,505 / mes*   Ciudad de México
# 1      $13,657 / mes*   Ciudad de México
# 2      $13,296 / mes*             Puebla
# 3      $13,273 / mes*          Monterrey
# 4      $13,047 / mes*   Ciudad de México
# ...                ...               ...
# 7503    $1,858 / mes*          Monterrey
# 7504    $1,846 / mes*   Ciudad de México
# 7505    $1,779 / mes*   Ciudad de México
# 7506    $1,767 / mes*   Ciudad de México
# 7507    $1,722 / mes*   Ciudad de México
#
# [7508 rows x 21 columns]

# %%
# Obtén la fecha actual con el formato dia-mes-año
# fecha_actual = datetime.now().strftime("%d-%m-%Y")
fecha_actual = datetime.now().strftime("%d-%m-%Y-%H")

# Agrega la fecha al nombre del DataFrame
nombre_del_df = f"THE_SKKKAPER_{fecha_actual}"

# Guarda el DataFrame en un archivo de CSV con el nuevo nombre
ruta_excel = f"{nombre_del_df}.csv" # Para excel usar .xlsx como extension
# THE_SKKKAPER_.to_excel(ruta_excel, index=False)

# Guarda el DataFrame en un archivo de CSV con el nuevo nombre
THE_SKKKAPER_Jupyter_.to_csv(ruta_excel, sep ="|" ,index=False)

print('Saved file: ' + ruta_excel)
# Out:
# Saved file: THE_SKKKAPER_15-10-2024-08.csv
